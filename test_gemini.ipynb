# %%
import os
from google import genai
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
KEY = os.environ["GOOGLE_KEY"]

# %%
client = genai.Client(api_key=KEY)

# %%
response = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents="Escribe un saludo desde Buenos Aires",
)

print(response.text)
# Out:
# ¡Hola! Te envío un saludo muy grande desde Buenos Aires. 🇦🇷
#
# Aquí te mando un poco de nuestra energía porteña: el aroma a café de alguna esquina de San Telmo, el movimiento constante de la Avenida Corrientes y un poco de frescura del Río de la Plata.
#
# Espero que estés teniendo un excelente día. ¿En qué puedo ayudarte hoy?
